# %% [markdown]
# ![image.png](attachment:431b9826-45b5-4f56-ac5c-7e573eab71d6.png)

# %% [markdown]
# # 知识库问答助手

# %%
from langchain_community.document_loaders import UnstructuredExcelLoader, Docx2txtLoader, PyPDFLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
import os
import dotenv
dotenv.load_dotenv()
os.environ["OPENAI_API_KEY"]= os.getenv("OPENAI_API_KEY")
os.environ["OPENAI_BASE_URL"]=os.getenv("OPENAI_BASE_URL")

class ChatDoc():
    def __init__(self):
        self.doc = None
        self.splitText = []#分割后的文本 split text
        self.template = [
            ("system","你是一个处理文档的秘书,你从不说自己是一个大模型或者AI助手,你会根据下面提供的上下文内容来继续回答问题.\n 上下文内容\n {context} \n"),
            ("human","你好！"),
            ("ai","您好，我是尚硅谷秘书"),
            ("human","{question}"),
        ]
        self.prompt = ChatPromptTemplate.from_messages(self.template)
    def getFile(self):
        doc = self.doc
        loaders = {
            "docx": Docx2txtLoader
        }
        file_extension = doc.split(".")[-1]
        loader_class = loaders.get(file_extension)
        if loader_class:
            try:
                loader = loader_class(doc)
                text = loader.load()
                return text
            except Exception as e:
                print(f"Error loading {file_extension} files:{e}")
        else:
            print(f"Unsupported file extension: {file_extension}")
            return None

#处理文档的函数
    def splitSentences(self):
        full_text = self.getFile()#获取文档内容 get the content of the document
        if full_text != None:
            #对文档进行分割
            # Split the document
            text_split = CharacterTextSplitter(
                chunk_size=500,
                chunk_overlap=100,
                separator="\n\n",
                length_function=len,
                is_separator_regex=False
            )
            texts = text_split.split_documents(full_text)
            self.splitText = texts

#向量化与向量存储
    def embeddingAndVectorDB(self):
        embeddings = OpenAIEmbeddings()
        db = Chroma.from_documents(
            documents=self.splitText,
            embedding=embeddings,
        )
        return db

#提问并找到相关的文本块
    def askAndFindFiles(self, question):
        db = self.embeddingAndVectorDB()
        print(db._collection.count())
        #retriever = db.as_retriever(search_type="mmr")
        retriever = db.as_retriever()
        return retriever.invoke(input=question)

#用自然语言和文档聊天
    def chatWithDoc(self, question):
        _content = ""
        context = self.askAndFindFiles(question)
        for i in context:
            _content += i.page_content
        print(f"{_content}", "_content")
        messages = self.prompt.format_messages(context=_content, question=question)
        print("message:", messages)
        llm = ChatOpenAI(
            model="gpt-4",
            temperature=0,
)
        return llm.invoke(messages)
chat_doc = ChatDoc()
chat_doc.doc = "./13-sgg_chat.docx"
chat_doc.splitSentences()
response = chat_doc.chatWithDoc("尚硅地址在哪")
print(response.content)
# Out:
# 3
# 尚硅谷师资团队评估报告
#
# 一、机构基本信息
#
# 名称：尚硅谷教育科技有限公司
# 总部地址：北京市海淀区中关村软件园创新大厦B座5层
# 成立日期：2016年3月15日
# 法定代表人：张明哲
# 注册资本：人民币2000万元
# 员工规模：全职讲师150人，技术助教300人
# 官方电话：010-66669999
# 官方邮箱：hr@atguigu.com
#
# 二、师资团队核心优势
#
# 技术背景深厚
#
# 90%讲师来自BAT、字节跳动等一线互联网企业，平均技术从业年限8年+
#
# 35%讲师拥有开源项目贡献经历（如Apache、Linux基金会项目）
#
# 教学能力突出
#
# 所有讲师均通过“教学能力三级认证体系”（技术能力、课程设计、课堂表达）
#
# 学员平均评分4.9/5.0（2023年内部调研数据）
#
# 行业影响力显著
#
# 12位讲师担任Oracle/Red Hat/AWS认证官方考官
#
# 出版技术书籍28本，累计销量超50万册
#
# 三、师资结构分析
#
# 类别
#
# 人数
#
# 占比
#
# 典型代表
#
# 架构师级讲师
#
# 25
#
# 16.7%
#
# 前阿里P9分布式系统专家
#
# 高级研发讲师
#
# 80
#
# 53.3%
#
# 腾讯T4级后台开发工程师
#
# 新兴领域讲师AI编程工具普及对传统教学内容的冲击
#
# 需持续增加AIGC、量子计算等前沿领域师资
#
# 区域发展不均衡
#
# 80%优质讲师集中在北京/深圳校区
#
# 二三线城市分校师资力量待加强
#
# 同业竞争加剧
#
# 头部竞品机构讲师薪资涨幅达25%（2023年行业报告）
#
# 六、优化建议
#
# 人才策略
#
# 设立“技术前瞻性研究基金”，鼓励讲师参与尖端项目
#
# 实施“地域津贴计划”平衡师资分布
#
# 课程升级
#
# 每季度开展“技术雷达”研讨会，动态调整课程大纲
#
# 开发AI助教系统辅助个性化教学
#
# 品牌建设
#
# 打造5-10名“明星讲师”IP（技术自媒体/行业峰会曝光）
#
# 七、结论
#
# 尚硅谷师资团队在技术深度与教学实效性方面处于行业领先地位，但需警惕技术变革带来的挑战。建议通过“技术+教学”双轨培养机制巩固核心竞争力，同时加强区域化布局以应对市场分化。
#
# 报告撰写日期：2023年12月1日
# 分析师：教育产业研究中心三、师资结构分析
#
# 类别
#
# 人数
#
# 占比
#
# 典型代表
#
# 架构师级讲师
#
# 25
#
# 16.7%
#
# 前阿里P9分布式系统专家
#
# 高级研发讲师
#
# 80
#
# 53.3%
#
# 腾讯T4级后台开发工程师
#
# 新兴领域讲师
#
# 45
#
# 30%
#
# 原字节AIGC项目组核心成员
#
# 教学方向覆盖：
#
# 后端开发（Java/Go/Python）
#
# 大数据（Hadoop/Spark/Flink）
#
# 人工智能（机器学习/深度学习）
#
# 云原生（K8s/Service Mesh）
#
# 四、教研成果
#
# 课程体系
#
# 累计开发课程1200+课时，年更新率40%
#
# 15门课程入选工信部“紧缺人才培养计划”
#
# 学员成就
#
# 2023年学员平均就业薪资18K/月（高于行业均值32%）
#
# 30名学员获Github年度Star贡献者
#
# 企业合作
#
# 与200+企业建立人才输送通道（含华为、蚂蚁集团等）
#
# 五、潜在风险提示
#
# 技术迭代压力
#
# AI编程工具普及对传统教学内容的冲击
#
# 需持续增加AIGC、量子计算等前沿领域师资
#
# 区域发展不均衡
#
# 80%优质讲师集中在北京/深圳校区
#
# 二三线城市分校师资力量待加强
#
# 同业竞争加剧 _content
# message: [SystemMessage(content='你是一个处理文档的秘书,你从不说自己是一个大模型或者AI助手,你会根据下面提供的上下文内容来继续回答问题.\n 上下文内容\n 尚硅谷师资团队评估报告\n\n一、机构基本信息\n\n名称：尚硅谷教育科技有限公司\n总部地址：北京市海淀区中关村软件园创新大厦B座5层\n成立日期：2016年3月15日\n法定代表人：张明哲\n注册资本：人民币2000万元\n员工规模：全职讲师150人，技术助教300人\n官方电话：010-66669999\n官方邮箱：hr@atguigu.com\n\n二、师资团队核心优势\n\n技术背景深厚\n\n90%讲师来自BAT、字节跳动等一线互联网企业，平均技术从业年限8年+\n\n35%讲师拥有开源项目贡献经历（如Apache、Linux基金会项目）\n\n教学能力突出\n\n所有讲师均通过“教学能力三级认证体系”（技术能力、课程设计、课堂表达）\n\n学员平均评分4.9/5.0（2023年内部调研数据）\n\n行业影响力显著\n\n12位讲师担任Oracle/Red Hat/AWS认证官方考官\n\n出版技术书籍28本，累计销量超50万册\n\n三、师资结构分析\n\n类别\n\n人数\n\n占比\n\n典型代表\n\n架构师级讲师\n\n25\n\n16.7%\n\n前阿里P9分布式系统专家\n\n高级研发讲师\n\n80\n\n53.3%\n\n腾讯T4级后台开发工程师\n\n新兴领域讲师AI编程工具普及对传统教学内容的冲击\n\n需持续增加AIGC、量子计算等前沿领域师资\n\n区域发展不均衡\n\n80%优质讲师集中在北京/深圳校区\n\n二三线城市分校师资力量待加强\n\n同业竞争加剧\n\n头部竞品机构讲师薪资涨幅达25%（2023年行业报告）\n\n六、优化建议\n\n人才策略\n\n设立“技术前瞻性研究基金”，鼓励讲师参与尖端项目\n\n实施“地域津贴计划”平衡师资分布\n\n课程升级\n\n每季度开展“技术雷达”研讨会，动态调整课程大纲\n\n开发AI助教系统辅助个性化教学\n\n品牌建设\n\n打造5-10名“明星讲师”IP（技术自媒体/行业峰会曝光）\n\n七、结论\n\n尚硅谷师资团队在技术深度与教学实效性方面处于行业领先地位，但需警惕技术变革带来的挑战。建议通过“技术+教学”双轨培养机制巩固核心竞争力，同时加强区域化布局以应对市场分化。\n\n报告撰写日期：2023年12月1日\n分析师：教育产业研究中心三、师资结构分析\n\n类别\n\n人数\n\n占比\n\n典型代表\n\n架构师级讲师\n\n25\n\n16.7%\n\n前阿里P9分布式系统专家\n\n高级研发讲师\n\n80\n\n53.3%\n\n腾讯T4级后台开发工程师\n\n新兴领域讲师\n\n45\n\n30%\n\n原字节AIGC项目组核心成员\n\n教学方向覆盖：\n\n后端开发（Java/Go/Python）\n\n大数据（Hadoop/Spark/Flink）\n\n人工智能（机器学习/深度学习）\n\n云原生（K8s/Service Mesh）\n\n四、教研成果\n\n课程体系\n\n累计开发课程1200+课时，年更新率40%\n\n15门课程入选工信部“紧缺人才培养计划”\n\n学员成就\n\n2023年学员平均就业薪资18K/月（高于行业均值32%）\n\n30名学员获Github年度Star贡献者\n\n企业合作\n\n与200+企业建立人才输送通道（含华为、蚂蚁集团等）\n\n五、潜在风险提示\n\n技术迭代压力\n\nAI编程工具普及对传统教学内容的冲击\n\n需持续增加AIGC、量子计算等前沿领域师资\n\n区域发展不均衡\n\n80%优质讲师集中在北京/深圳校区\n\n二三线城市分校师资力量待加强\n\n同业竞争加剧 \n', additional_kwargs={}, response_metadata={}), HumanMessage(content='你好！', additional_kwargs={}, response_metadata={}), AIMessage(content='您好，我是尚硅谷秘书', additional_kwargs={}, response_metadata={}, tool_calls=[], invalid_tool_calls=[]), HumanMessage(content='尚硅地址在哪', additional_kwargs={}, response_metadata={})]
# 尚硅谷教育科技有限公司的总部地址位于北京市海淀区中关村软件园创新大厦B座5层。
